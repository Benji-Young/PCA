# %% [markdown]
# <a href="https://colab.research.google.com/github/Benji-Young/PCA/blob/main/PCA2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn.decomposition import PCA
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt

# Load the Iris dataset
iris = load_iris()
X = iris.data  # Features

# Create a PCA instance and select one component
pca = PCA(n_components=1)

# Fit and transform the data
X_new = pca.fit_transform(X)

# Print the explained variance ratio for each principal component
print(pca.explained_variance_ratio_)

# Visualization (modified for PC1 only)
plt.scatter(X_new[:, 0], np.zeros_like(X_new[:, 0]), c=iris.target)  # Project onto the y=0 line
plt.xlabel('Principal Component 1')
plt.title('Iris Dataset: PC1 Projection')
plt.show()
# Out:
# [0.92461872]
